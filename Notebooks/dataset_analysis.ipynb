# %% [markdown]
# # Imports

# %%
import pandas as pd

# %% [markdown]
# # Dataset Analysis

# %%
df = pd.read_csv("../data/raw/list_attr_celeba.csv")

# Basic Dataset Analysis
print("Dataframe Shape: ", df.shape)
print("---")

print("Dataframe Columns: ", df.columns.tolist())
print("---")

# Check the distribution of classification labels for the attributes we are interested in
print("No of: ", df["Eyeglasses"].value_counts())
print("---")

print("No of: ", df["Wearing_Hat"].value_counts())
print("---")

print("No of: ", df["Young"].value_counts())

print(df.columns[:5])
# Out:
# Dataframe Shape:  (202599, 41)
# ---
# Dataframe Columns:  ['image_id', '5_o_Clock_Shadow', 'Arched_Eyebrows', 'Attractive', 'Bags_Under_Eyes', 'Bald', 'Bangs', 'Big_Lips', 'Big_Nose', 'Black_Hair', 'Blond_Hair', 'Blurry', 'Brown_Hair', 'Bushy_Eyebrows', 'Chubby', 'Double_Chin', 'Eyeglasses', 'Goatee', 'Gray_Hair', 'Heavy_Makeup', 'High_Cheekbones', 'Male', 'Mouth_Slightly_Open', 'Mustache', 'Narrow_Eyes', 'No_Beard', 'Oval_Face', 'Pale_Skin', 'Pointy_Nose', 'Receding_Hairline', 'Rosy_Cheeks', 'Sideburns', 'Smiling', 'Straight_Hair', 'Wavy_Hair', 'Wearing_Earrings', 'Wearing_Hat', 'Wearing_Lipstick', 'Wearing_Necklace', 'Wearing_Necktie', 'Young']
# ---
# No of:  Eyeglasses
# -1    189406
#  1     13193
# Name: count, dtype: int64
# ---
# No of:  Wearing_Hat
# -1    192781
#  1      9818
# Name: count, dtype: int64
# ---
# No of:  Young
#  1    156734
# -1     45865
# Name: count, dtype: int64
# Index(['image_id', '5_o_Clock_Shadow', 'Arched_Eyebrows', 'Attractive',
# ...
